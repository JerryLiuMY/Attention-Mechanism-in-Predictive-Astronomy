# %%
import matplotlib 
from utils.data_loader import DataLoader
instance = DataLoader(1001115026824, is_short=False)
data_dict = instance.load_partition_data()

# %%
from model.carma import Carma
carma_instance = Carma(data_dict)
# Out:
# array([1844.98468, 1844.98812, 1844.99152, 1858.95532, 1858.96049,
#        1858.96566, 1858.97091, 2035.61426, 2035.62615, 2035.63196,
#        2046.6202 , 2046.63111, 2046.63649, 1996.67116, 1996.68706,
#        1996.69509, 2018.59084, 2018.60445, 2018.6113 , 1973.77578,
#        1973.79072, 1973.79812, 2198.98238, 2198.98936, 2198.99635,
#        2199.00328, 2261.83403, 2261.8397 , 2261.84544, 2261.85116,
#        2238.88781, 2238.89597, 2238.90417, 2238.91237, 2254.87607,
#        2254.88235, 2254.88872, 2254.89511, 2212.94489, 2212.9532 ,
#        2212.96158, 2212.96996, 2225.93608, 2225.94604, 2225.95539,
#        2225.96463,  745.97448,  745.98224,  745.99002,  745.99777,
#        1258.67477, 1258.68272, 1258.69068, 1258.69861, 2342.69288,
#        2342.69963, 2342.70649, 2342.71327, 2351.65154, 2351.65661,
#        2351.66171, 2351.66682, 2369.64454, 2369.65252, 2369.66055,
#        2369.66866, 2580.97431, 2580.97952, 2580.9846 , 2580.98992,
# ...

# %%
# pq_list = carma_instance.fit_pq()

# %%
matplotlib.rc('figure', figsize=(10, 6))
carma_instance.fit_model()
# Out:
# Calculating PSD Lorentzian parameters...
# Calculating coefficients of AR polynomial...
# Calculating sigma...
# Calculating log-likelihoods...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c610dae845c1> in <module>()
#       1 matplotlib.rc('figure', figsize=(10, 6))
#       2 carma_instance.fit_model()
# ----> 3 t_list_cross.min
#
# NameError: name 't_list_cross' is not defined

# %%
carma_instance.power_spectrum()

# %%
carma_instance.sample_interpolation()

# %%
carma_instance.average_forecasting()

# %%
carma_instance.sample_forecasting()
