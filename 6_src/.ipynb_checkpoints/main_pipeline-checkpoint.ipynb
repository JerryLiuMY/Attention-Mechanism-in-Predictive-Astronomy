# %% [markdown]
# ## Main Pipeline

# %%
from main_pipeline import MainPipeline
instance = MainPipeline(1001115026824)
# instance.prepare_all_data()
# instance.prepare_individual_data()
instance.load_individual_data()
# Out:
# Using TensorFlow backend.

# %%
# instance.run_carama()

# %%
instance.run_vanilla_lstm()
# Out:
# fitting 1001115026824_vanilla_lstm_phased_model.pkl model
# WARNING:tensorflow:From /Users/mingyu/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:72: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/mingyu/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:515: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/mingyu/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4048: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/mingyu/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:782: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /Users/mingyu/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:984: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Users/mingyu/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:971: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
#  - 1s - loss: 0.1601
# Epoch 2/100
#  - 0s - loss: 0.1542
# Epoch 3/100
#  - 0s - loss: 0.1485
# Epoch 4/100
#  - 0s - loss: 0.1431
# Epoch 5/100
#  - 0s - loss: 0.1377
# Epoch 6/100
#  - 0s - loss: 0.1325
# Epoch 7/100
#  - 0s - loss: 0.1276
# Epoch 8/100
#  - 0s - loss: 0.1228
# Epoch 9/100
#  - 0s - loss: 0.1181
# Epoch 10/100
#  - 0s - loss: 0.1136
# Epoch 11/100
#  - 0s - loss: 0.1093
# Epoch 12/100
#  - 0s - loss: 0.1051
# Epoch 13/100
#  - 0s - loss: 0.1012
# Epoch 14/100
#  - 0s - loss: 0.0973
# Epoch 15/100
#  - 0s - loss: 0.0936
# Epoch 16/100
#  - 0s - loss: 0.0901
# Epoch 17/100
#  - 0s - loss: 0.0867
# Epoch 18/100
#  - 0s - loss: 0.0834
# Epoch 19/100
#  - 0s - loss: 0.0803
# Epoch 20/100
#  - 0s - loss: 0.0773
# Epoch 21/100
#  - 0s - loss: 0.0744
# Epoch 22/100
#  - 0s - loss: 0.0717
# Epoch 23/100
#  - 0s - loss: 0.0690
# Epoch 24/100
#  - 0s - loss: 0.0665
# Epoch 25/100
#  - 0s - loss: 0.0639
# Epoch 26/100
#  - 0s - loss: 0.0606
# Epoch 27/100
#  - 0s - loss: 0.0558
# Epoch 28/100
#  - 0s - loss: 0.0281
# Epoch 29/100
#  - 0s - loss: 0.0270
# Epoch 30/100
#  - 0s - loss: 0.0242
# Epoch 31/100
#  - 0s - loss: 0.0239
# Epoch 32/100
#  - 0s - loss: 0.0234
# Epoch 33/100
#  - 0s - loss: 0.0229
# Epoch 34/100
#  - 0s - loss: 0.0226
# Epoch 35/100
#  - 0s - loss: 0.0223
# Epoch 36/100
#  - 0s - loss: 0.0220
# Epoch 37/100
#  - 0s - loss: 0.0217
# Epoch 38/100
#  - 0s - loss: 0.0215
# Epoch 39/100
#  - 0s - loss: 0.0212
# Epoch 40/100
#  - 0s - loss: 0.0209
# Epoch 41/100
#  - 0s - loss: 0.0208
# Epoch 42/100
#  - 0s - loss: 0.0205
# Epoch 43/100
#  - 0s - loss: 0.0202
# Epoch 44/100
#  - 0s - loss: 0.0200
# Epoch 45/100
#  - 0s - loss: 0.0198
# Epoch 46/100
#  - 0s - loss: 0.0196
# Epoch 47/100
#  - 0s - loss: 0.0194
# Epoch 48/100
#  - 0s - loss: 0.0192
# Epoch 49/100
#  - 0s - loss: 0.0189
# Epoch 50/100
#  - 0s - loss: 0.0187
# Epoch 51/100
#  - 0s - loss: 0.0185
# Epoch 52/100
#  - 0s - loss: 0.0183
# Epoch 53/100
#  - 0s - loss: 0.0181
# Epoch 54/100
#  - 0s - loss: 0.0179
# Epoch 55/100
#  - 0s - loss: 0.0176
# Epoch 56/100
#  - 0s - loss: 0.0174
# Epoch 57/100
#  - 0s - loss: 0.0171
# Epoch 58/100
#  - 0s - loss: 0.0169
# Epoch 59/100
#  - 0s - loss: 0.0167
# Epoch 60/100
#  - 0s - loss: 0.0165
# Epoch 61/100
#  - 0s - loss: 0.0163
# Epoch 62/100
#  - 0s - loss: 0.0161
# Epoch 63/100
#  - 0s - loss: 0.0159
# Epoch 64/100
#  - 0s - loss: 0.0158
# Epoch 65/100
#  - 0s - loss: 0.0156
# Epoch 66/100
#  - 0s - loss: 0.0154
# Epoch 67/100
#  - 0s - loss: 0.0152
# Epoch 68/100
#  - 0s - loss: 0.0151
# Epoch 69/100
#  - 0s - loss: 0.0149
# Epoch 70/100
#  - 0s - loss: 0.0147
# Epoch 71/100
#  - 0s - loss: 0.0146
# Epoch 72/100
#  - 0s - loss: 0.0144
# Epoch 73/100
#  - 0s - loss: 0.0142
# Epoch 74/100
#  - 0s - loss: 0.0141
# Epoch 75/100
#  - 0s - loss: 0.0140
# Epoch 76/100
#  - 0s - loss: 0.0138
# Epoch 77/100
#  - 0s - loss: 0.0137
# Epoch 78/100
#  - 0s - loss: 0.0135
# Epoch 79/100
#  - 0s - loss: 0.0133
# Epoch 80/100
#  - 0s - loss: 0.0133
# Epoch 81/100
#  - 0s - loss: 0.0131
# Epoch 82/100
#  - 0s - loss: 0.0130
# Epoch 83/100
#  - 0s - loss: 0.0129
# Epoch 84/100
#  - 0s - loss: 0.0128
# Epoch 85/100
#  - 0s - loss: 0.0127
# Epoch 86/100
#  - 0s - loss: 0.0126
# Epoch 87/100
#  - 0s - loss: 0.0125
# Epoch 88/100
#  - 0s - loss: 0.0124
# Epoch 89/100
#  - 0s - loss: 0.0122
# Epoch 90/100
#  - 0s - loss: 0.0122
# Epoch 91/100
#  - 0s - loss: 0.0121
# Epoch 92/100
#  - 0s - loss: 0.0120
# Epoch 93/100
#  - 0s - loss: 0.0120
# Epoch 94/100
#  - 0s - loss: 0.0119
# Epoch 95/100
#  - 0s - loss: 0.0119
# Epoch 96/100
#  - 0s - loss: 0.0118
# Epoch 97/100
#  - 0s - loss: 0.0118
# Epoch 98/100
#  - 0s - loss: 0.0117
# Epoch 99/100
#  - 0s - loss: 0.0117
# Epoch 100/100
#  - 0s - loss: 0.0117
# 75/75 [==============================] - 0s 1ms/step
# 75/75 [==============================] - 0s 83us/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-871c8b58f071> in <module>
# ----> 1 instance.run_vanilla_lstm()
#
# ~/Desktop/Attention-Mechanism-in-Predictive-Astronomy/6_src/main_pipeline.py in run_vanilla_lstm(self)
#     189                 vanilla_lstm_model = vanilla_lstm.fit_model(self.train_X, self.train_y, self.cross_X, self.cross_y, self.test_X, self.test_y)
#     190                 with open(os.path.join(self.vanilla_lstm_data_folder, vanilla_lstm_model_name), 'wb') as handle:
# --> 191                     pickle.dump(vanilla_lstm_model, handle)
#     192                     print('vanilla lstm model: %s is loaded' % vanilla_lstm_model_name)
#     193
#
# TypeError: can't pickle _thread.RLock objects
